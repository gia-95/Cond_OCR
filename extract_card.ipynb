# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
imgpath = 'documenti/documento6.jpg'
img = cv2.imread(imgpath)

###              ymin,        ymax,        xmin,       xmax
box = np.array([877.586670, 1189.484497, 268.870148, 762.843262])
box = box.astype('int64')

card = img[box[0]:box[1], box[2]:box[3]]

plt.imshow(card)
